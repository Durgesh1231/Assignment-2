# %%
ans1.

comment code in python we use three time single quotea '''    ''' for multiple line
we use hashtags # for single line comment in python.
there are 3 type of comments in python.
a) Single-line, we use # eg. #python programming   
b) Multiple-line, we use '''  ''' eg ''' python programming in 
                                         in pw skills'''
c)  docstring-Python provides an in-built feature called docstrings for commenting on modules, methods, functions, objects, and classes. They are written in the first line after defining a module, function, method, etc., using three quotation marks (‘’ or “”).

Ans 2.

Variables are container for storing data values
a=5

Ans 3.

There are 2 type of conversion of datatype in python
 
 a) explicit function - In Explicit Type Conversion in Python, the data type is manually changed by the user as per their requirement.
    eg. 1.int(a, base): This function converts any data type to integer. ‘Base’ specifies the base in which string is if the data type is a string.
        2.float(): This function is used to convert any data type to a floating-point number.
        
        a="10010"
        b=float(a)
        print("after changing to float: ",end=" "
        print(b)
        
 b) implicit function
    eg x=10
    print("type(x))  # int type
    y=10.6
    print(type(y))   # float type 
    z=x+y
    print(type(z))   # float type
    As we can see the data type of ‘z’ got automatically changed to the “float” type while one variable x is of integer type while the other variable y is of float type.
    

Ans 4.

The most basic and easy way to run a Python script is by using the python command. You need to open a command line and type the word python followed by the path to your script file like this:
   
   Python first_script.py
   RamChandra
   
Ans 5. 
my_list=[1,2,3,4,5]
sub_list=slice(1,3)
print(sub_list[])

Ans 6.
Complex no. is a combination of real no. and imaginary no. In maths it is denoted by a+ib
in Python it is denoted by a+bj

Ans 7. 
var_age=25

Ans 8.
var_price=9.99
type(var_price)

Ans 9.
Name="RamChandra"
print(name)
          
Ans 10.
String="Hello,World!"
print(String[-6:-1]
      
Ans 11.
is_Student=
